# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("top_hits_2007-2020.csv")
# Drop the null columns where all values are null
# df = df.dropna(axis='columns', how='all')
# Drop the null rows
data=df.drop(columns=["Artist and Title", ""'(x?)'"",'Track','track_id'])

audio_only = data.fillna(0)
audio_only
# Out:
#        Pos  Wks   T10   Pk  PkStreams      Total  danceability  energy  key  \
# 0        1  123  26.0    1   19553820  636825483         0.585   0.520    5
# 1        2  147  30.0    2   11030276  585052066         0.732   0.750   11
# 2      141   79   0.0   17    3848737  179292836         0.732   0.750   11
# 3      709   19   0.0   40    3443592   47632753         0.732   0.750   11
# 4      798   14   1.0    9    7054307   41594283         0.732   0.750   11
# ...    ...  ...   ...  ...        ...        ...           ...     ...  ...
# 4774  4847    1   0.0  268      72612      72612         0.480   0.506   11
# 4775  4848    1   0.0  243      72256      72256         0.594   0.630    6
# 4776  4850    1   0.0  247      70155      70155         0.690   0.805    7
# 4777  4851    1   0.0  248      70035      70035         0.646   0.657    0
# 4778  4853    1   0.0  248      67174      67174         0.645   0.606   10
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -6.136     0       0.0712       0.12400          0.000070    0.1310
# 1       -6.366     0       0.2310       0.00264          0.000000    0.1090
# 2       -6.366     0       0.2310       0.00264          0.000000    0.1090
# 3       -6.366     0       0.2310       0.00264          0.000000    0.1090
# 4       -6.366     0       0.2310       0.00264          0.000000    0.1090
# ...        ...   ...          ...           ...               ...       ...
# 4774    -5.554     1       0.3810       0.54900          0.000000    0.0916
# 4775    -7.323     0       0.0268       0.04310          0.000003    0.0974
# 4776    -5.979     0       0.0329       0.01960          0.002820    0.2810
# 4777    -5.300     1       0.0628       0.14500          0.000057    0.4590
# 4778    -8.074     0       0.5120       0.29200          0.000000    0.1290
#
#       valence    tempo  duration_ms  time_signature
# 0       0.129  159.801       218147               4
# 1       0.401  155.096       182707               4
# 2       0.401  155.096       182707               4
# 3       0.401  155.096       182707               4
# 4       0.401  155.096       182707               4
# ...       ...      ...          ...             ...
# 4774    0.708  177.440       224267               4
# 4775    0.365  117.010       258227               4
# 4776    0.738  123.871       269373               4
# 4777    0.413  139.990       173214               4
# 4778    0.121  118.800       301960               4
#
# [4779 rows x 19 columns]

# %%
X = audio_only.drop("Total", axis = 1)
y = audio_only["Total"]

###use this for _featureimportances function with Random Forest
feature_names = audio_only.columns
print("Shape", X.shape, y.shape)
y = y.values.reshape(-1,1)
y
print("Shape", X.shape, y.shape)
# Out:
# Shape (4779, 18) (4779,)
# Shape (4779, 18) (4779, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()

# %%
model.fit(X, y)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.8727011525236006
# Testing Score: 0.8839791271436377

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-7941edcfe8e7> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, y_predicted)
#       3 cm
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
